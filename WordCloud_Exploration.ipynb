# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pandas as pd
import os

os.chdir(r"E:\Download\Applied ML Project")
df = pd.read_csv("listings.csv")

df.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  49091  https://www.airbnb.com/rooms/49091  20190318042744   2019-03-18
# 1  50646  https://www.airbnb.com/rooms/50646  20190318042744   2019-03-18
# 2  56334  https://www.airbnb.com/rooms/56334  20190318042744   2019-03-18
# 3  71609  https://www.airbnb.com/rooms/71609  20190318042744   2019-03-18
# 4  71896  https://www.airbnb.com/rooms/71896  20190318042744   2019-03-18
#
#                                   name  \
# 0    COZICOMFORT LONG TERM STAY ROOM 2
# 1      Pleasant Room along Bukit Timah
# 2                          COZICOMFORT
# 3  Ensuite Room (Room 1 & 2) near EXPO
# 4      B&B  Room 1 near Airport & EXPO
#
#                                              summary  \
# 0                                                NaN
# 1  Fully furnished bedroom with a nice view on th...
# 2                                                NaN
# 3  For 3 (Website hidden by Airbnb) room 1&2 and ...
# ...

# %%
df['price'] = df['price'].replace('[\$,]', '', regex=True).astype(float)
df['amenities'] = df['amenities'].str.replace('[^\w\s]', ' ')
df['description'] = df['amenities'].str.replace('[^\w\s]', ' ')

# %%
text_amenities = df.loc[df['price'] > 500, 'amenities']

wordcloud = WordCloud().generate(''.join(text_amenities))
plt.imshow(wordcloud.recolor(random_state=1))
plt.title('Most mentioned amenities with price > 500/day')
plt.axis("off")
plt.show()

text_description = df.loc[df['price'] > 500, 'description']

wordcloud = WordCloud().generate(''.join(text_description))
plt.imshow(wordcloud.recolor(random_state=1))
plt.title('Most mentioned description with price > 500/day')
plt.axis("off")
plt.show()

# %%
text_amenities = df.loc[(df['price'] <=500) & (df['price'] >400), 'amenities']

wordcloud = WordCloud().generate(''.join(text_amenities))
plt.imshow(wordcloud.recolor(random_state=1))
plt.title('Most mentioned amenities with price at 400-500/day')
plt.axis("off")
plt.show()

text_description = df.loc[(df['price'] <=500) & (df['price'] >400), 'description']
wordcloud = WordCloud().generate(''.join(text_description))
plt.imshow(wordcloud.recolor(random_state=1))
plt.title('Most mentioned description with price at 400-500/day')
plt.axis("off")
plt.show()

# %%
text_amenities = df.loc[(df['price'] <=400) & (df['price'] >300), 'amenities']

wordcloud = WordCloud().generate(''.join(text_amenities))
plt.imshow(wordcloud.recolor(random_state=1))
plt.title('Most mentioned amenities with price at 300-400/day')
plt.axis("off")
plt.show()

text_description = df.loc[(df['price'] <=400) & (df['price'] >300), 'description']
wordcloud = WordCloud().generate(''.join(text_description))
plt.imshow(wordcloud.recolor(random_state=1))
plt.title('Most mentioned description with price at 300-400/day')
plt.axis("off")
plt.show()

# %%
text_amenities = df.loc[(df['price'] <=300) & (df['price'] >200), 'amenities']

wordcloud = WordCloud().generate(''.join(text_amenities))
plt.imshow(wordcloud.recolor(random_state=1))
plt.title('Most mentioned amenities with price at 200-300/day')
plt.axis("off")
plt.show()

text_description = df.loc[(df['price'] <=300) & (df['price'] >200), 'description']
wordcloud = WordCloud().generate(''.join(text_description))
plt.imshow(wordcloud.recolor(random_state=1))
plt.title('Most mentioned description with price at 200-300/day')
plt.axis("off")
plt.show()

# %%
text_amenities = df.loc[(df['price'] <=200) & (df['price'] >100), 'amenities']

wordcloud = WordCloud().generate(''.join(text_amenities))
plt.imshow(wordcloud.recolor(random_state=1))
plt.title('Most mentioned amenities with price at 100-200/day')
plt.axis("off")
plt.show()

text_description = df.loc[(df['price'] <=200) & (df['price'] >100), 'description']
wordcloud = WordCloud().generate(''.join(text_description))
plt.imshow(wordcloud.recolor(random_state=1))
plt.title('Most mentioned description with price at 100-200/day')
plt.axis("off")
plt.show()

# %%
text_amenities = df.loc[df['price'] <100, 'amenities']

wordcloud = WordCloud().generate(''.join(text_amenities))
plt.imshow(wordcloud.recolor(random_state=1))
plt.title('Most mentioned amenities with price at 100-200/day')
plt.axis("off")
plt.show()

text_description = df.loc[df['price'] <100, 'description']
wordcloud = WordCloud().generate(''.join(text_description))
plt.imshow(wordcloud.recolor(random_state=1))
plt.title('Most mentioned description with price < 100/day')
plt.axis("off")
plt.show()
